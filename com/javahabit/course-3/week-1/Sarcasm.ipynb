# %%
# Sequence 5

# %% [markdown]
# ## Detect Sarcasm from a news source
#
# - Read json the two json file and put them in list

# %%
import json
filePath = 'C:/Dinesh/github-proj/tensorflow-cert/data/sarcasm/Sarcasm_Headlines_Dataset.json'
data =[]
with open(filePath,'r') as fp:
    data=fp.readlines()

# %%
print(len(data))
#append , after each line
filePath = 'C:/Dinesh/github-proj/tensorflow-cert/data/sarcasm/Sarcasm_Headlines_Dataset_v2.json'
with open(filePath,'r') as fp:
    data2= fp.readlines()
# Out:
# 26709

# %%
#append , after each line
for line in data2:
    data.append(line)

# %%
print(data[0])
len(data)
# Out:
# {"article_link": "https://www.huffingtonpost.com/entry/versace-black-code_us_5861fbefe4b0de3a08f600d5", "headline": "former versace store clerk sues over secret 'black code' for minority shoppers", "is_sarcastic": 0}
# 55328

# %%
articles=[]
headlines=[]
sarcastic=[]
for item in data:
    articles.append(json.loads(item)['article_link'])
    headlines.append(json.loads(item)['headline'])
    sarcastic.append(json.loads(item)['is_sarcastic'])

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(headlines)

word_index = tokenizer.word_index
print(len(word_index))
print(word_index)
sequences = tokenizer.texts_to_sequences(headlines)
padded = pad_sequences(sequences, padding='post')
print(padded[0])
print(padded.shape)
# Out:
# 30885
# ...

# %%
print(sequences)
# Out:
# [[315, 15933, 643, 3418, 2442, 46, 387, 2722, 15934, 6, 2723, 8923], [4, 8548, 3509, 2724, 22, 2, 177, 8924, 418, 3081, 6, 254, 9, 1060], [145, 765, 2, 930, 1819, 2195, 604, 4801, 223, 131, 39, 45, 2, 11335], [1557, 35, 222, 406, 2, 1857, 29, 324, 22, 10, 2999, 1449, 7369, 964], [766, 738, 4971, 820, 11336, 627, 599, 5, 4, 98, 1361, 91], [11337, 4, 378, 78], [4, 7370, 349, 6, 446, 3979, 2300, 1493], [21, 414, 39, 1144, 31, 158, 2, 100, 80, 18, 154, 6, 32, 341], [259, 3799, 7371, 567, 5570, 1701, 139], [2196, 345, 360, 404, 64, 15935, 6, 4, 4103], [3000, 1646, 4972, 14, 37, 4104, 7372, 5, 2148, 1127], [276, 829, 464, 8, 1612, 1820, 9, 3800], [238, 518, 3082, 13, 9, 898, 232, 366, 2, 4362, 15936, 8925], [236, 4105, 8926, 3419, 38, 230, 15937, 6, 7, 162], [15938, 1402, 650, 670, 5, 327, 3, 1098], [558, 2148, 11338, 122, 11339, 6, 11340, 4973, 1983], [2653, 1423, 374, 47, 3980, 343, 324, 1061, 2, 24, 15225, 19, 1099, 390, 105, 1170], [1525, 8549, 2826, 8550, 19, 7373, 1217], [11341, 866,
# ...
